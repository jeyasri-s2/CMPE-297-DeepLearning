# %% [markdown]
# <a href="https://colab.research.google.com/github/plodha/CMPE-297-DeepLearning/blob/main/CMPE-297-DeepLearning/Notebook/DLProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!wget -P "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning" https://cs.stanford.edu/group/mlgroup/MURA-v1.1.zip

# %%
#!unzip "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/MURA-v1.1.zip" -d "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/"

# %%
# !unzip "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/MURA-v1.1.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#    creating: MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/image1.png
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/image3.png
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/image2.png
#    creating: MURA-v1.1/train/XR_SHOULDER/patient01016/
#    creating: MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/image1.png
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/image3.png
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/image2.png
#    creating: MURA-v1.1/train/XR_SHOULDER/patient01182/
#    creating: MURA-v1.1/train/XR_SHOULDER/patient01182/study1_positive/
#   inflating: MURA-v1.1/train/XR_SHOULDER/patient01182/study1_positive/image1.png
# ...

# %%
# !pip install torch==1.2.0 torchvision==0.4.0 tqdm opencv-python Pillow==8.0.1 tensorboardX==1.4
# Out:
# ...
#      |████████████████████████████████| 748.9MB 13kB/s
# ...
#      |████████████████████████████████| 8.8MB 42.3MB/s
# ...
#      |████████████████████████████████| 2.2MB 43.3MB/s
# ...
#      |████████████████████████████████| 71kB 11.2MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
#   Found existing installation: torchvision 0.8.1+cu101
#     Uninstalling torchvision-0.8.1+cu101:
#       Successfully uninstalled torchvision-0.8.1+cu101
# ...

# %%
#!pip install tensorboardX

# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
# !nvidia-smi
# Out:
# Sun Nov  8 22:24:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls -l
# Out:
# total 12
# drwx------ 5 root root 4096 Nov  8 22:18 drive
# drwxr-xr-x 4 root root 4096 May 25  2018 MURA-v1.1
# drwxr-xr-x 1 root root 4096 Oct 28 16:30 sample_data

# %%
# !python "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/Project Files/main.py" --batch_size 128 --imsize 64 --dataset mura --adv_loss inverse --version sabigan_wrist --image_path . --use_tensorboard true --mura_class XR_WRIST --mura_type negative --model alpha --total_step 5000
# Out:
# Dataset lengh:  5765
# self.parallel:  False
# Generator(
#   (l1): Sequential(
#     (0): SpectralNorm(
#       (module): ConvTranspose2d(128, 512, kernel_size=(4, 4), stride=(1, 1))
#     )
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (l2): Sequential(
#     (0): SpectralNorm(
#       (module): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (l3): Sequential(
#     (0): SpectralNorm(
#       (module): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (l4): Sequential(
#     (0): SpectralNorm(
#       (module): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
# ...

# %%
# !zip -r "/content/logs.zip" "/content/logs"
# !zip -r "/content/models.zip" "/content/models"
# Out:
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/sabigan_wrist/ (stored 0%)
#   adding: content/logs/sabigan_wrist/events.out.tfevents.1604874251.9c0cad39347a (deflated 0%)
#   adding: content/models/ (stored 0%)
#   adding: content/models/sabigan_wrist/ (stored 0%)
#   adding: content/models/sabigan_wrist/2300_E.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/4600_E.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/2300_C.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/2300_D.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/2300_G.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/4600_G.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/4600_D.pth (deflated 8%)
#   adding: content/models/sabigan_wrist/4600_C.pth (deflated 8%)

# %%
from google.colab import files
files.download("/content/logs.zip")
files.download("/content/models.zip")
