# %% [markdown]
# <a href="https://colab.research.google.com/github/plodha/CMPE-297-DeepLearning/blob/main/Notebook/DLProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!wget -P "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning" https://cs.stanford.edu/group/mlgroup/MURA-v1.1.zip

# %%
#!unzip "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/MURA-v1.1.zip" -d "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/"

# %%
# !unzip "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/MURA-v1.1.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: MURA-v1.1/train/XR_WRIST/patient07962/study1_negative/image3.png
#   inflating: MURA-v1.1/train/XR_WRIST/patient07962/study1_negative/image4.png
#   inflating: MURA-v1.1/train/XR_WRIST/patient07962/study1_negative/image2.png
#    creating: MURA-v1.1/train/XR_WRIST/patient08232/
#    creating: MURA-v1.1/train/XR_WRIST/patient08232/study1_negative/
#   inflating: MURA-v1.1/train/XR_WRIST/patient08232/study1_negative/image1.png
#   inflating: MURA-v1.1/train/XR_WRIST/patient08232/study1_negative/image3.png
#   inflating: MURA-v1.1/train/XR_WRIST/patient08232/study1_negative/image2.png
#    creating: MURA-v1.1/train/XR_WRIST/patient04849/
#    creating: MURA-v1.1/train/XR_WRIST/patient04849/study1_positive/
#   inflating: MURA-v1.1/train/XR_WRIST/patient04849/study1_positive/image2.png
#   inflating: MURA-v1.1/train/XR_WRIST/patient04849/study1_positive/image3.png
# ...

# %%
#!pip install torch==1.2.0 torchvision==0.4.0 tqdm opencv-python Pillow==8.0.1 tensorboardX==2.1

# %%
# !pip install tensorboardX

# %%
# !nvidia-smi

# %%
# !ls -l

# %%
import torch
torch.cuda.is_available()

# %%
# !python "/content/drive/Shared drives/MeanSquare-Drive/Advanced-DeepLearning/Project Files/main.py" --batch_size 128 --imsize 64 --dataset mura --adv_loss inverse --version sabigan_wrist --image_path . --use_tensorboard false --mura_class XR_WRIST --mura_type negative --model alpha
